# %% [markdown]
# <a href="https://colab.research.google.com/github/KingsWorkflow/data-analysis-assginment1/blob/main/DataAnalysisAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# 1.Read the CSV File

# %%
sales_rec = pd.read_csv("/pandas_dataset.csv")
original_shape = sales_rec.shape
print(sales_rec.head())
# Out:
#    order_id customer_name     category       product       city  quantity  \
# 0       NaN           NaN          NaN           NaN        NaN       NaN
# 1    1001.0         Aarav  Electronics        Laptop  Kathmandu       2.0
# 2    1002.0          Sita    Furniture  Office Chair   Lalitpur       1.0
# 3    1003.0         Rohan  Electronics    Headphones  Bhaktapur       3.0
# 4    1004.0        Anisha     Clothing        Jacket  Kathmandu       2.0
#
#    unit_price order_date     status     sales   profit  discount
# 0         NaN        NaN        NaN       NaN      NaN       NaN
# 1     85000.0   1/5/2026  Completed  170000.0  34000.0   17000.0
# 2     18000.0   1/8/2026  Completed   18000.0   3600.0     900.0
# 3      4500.0  1/12/2026    Pending   13500.0   2700.0     675.0
# 4      6500.0  1/15/2026  Completed   13000.0   2600.0     650.0

# %% [markdown]
# 2.Rename Columns

# %%
sales_rec.columns = sales_rec.columns.str.lower().str.replace(" ", "_")

# %% [markdown]
#  3.Drop Unnecessary Rows

# %%
sales_rec = sales_rec.iloc[1:].reset_index(drop=True)

# %% [markdown]
# 4.Drop Columns

# %%
sales_rec =sales_rec.drop(columns=["product"])

# %% [markdown]
#  5.Count Missing Values

# %%
print(sales_rec.isnull().sum())
# Out:
# order_id         0
# customer_name    1
# category         0
# city             1
# quantity         1
# unit_price       1
# order_date       0
# status           1
# sales            3
# profit           3
# discount         3
# dtype: int64

# %% [markdown]
# 6.Handle Missing Values

# %% [markdown]
# a.Drop Rows Based on a Column

# %%
sales_rec = sales_rec.dropna(subset=["sales"])

# %% [markdown]
# b.Fill Missing Values

# %%
sales_rec["profit"] =sales_rec["profit"].fillna(sales_rec["profit"].mean())
sales_rec["discount"] = sales_rec["discount"].fillna(sales_rec["discount"].median())

# %% [markdown]
# 7.Handle Missing Categorical Data

# %%
sales_rec["customer_name"] =sales_rec["customer_name"].fillna("Unknown")

# %% [markdown]
# 8.Detect and Remove Duplicates

# %%
duplicate_count =sales_rec.duplicated(subset=["order_id"]).sum()
print(duplicate_count)
before_count = len(sales_rec)
sales_rec = sales_rec.drop_duplicates(subset=["order_id"])
sales_rec =sales_rec.reset_index(drop=True)
removed_count =before_count - len(sales_rec)
print(removed_count)
# Out:
# 3
# 3

# %% [markdown]
#  9.Filtering and creating new columns

# %%
costly_orders =sales_rec[sales_rec["unit_price"]>20000]
print(costly_orders)

done_orders = sales_rec[(sales_rec["unit_price"]>10000) & (sales_rec["status"]=="Completed")]
print(done_orders[["customer_name","category","status"]])

sales_rec["total_amount"] = sales_rec["quantity"] *sales_rec["unit_price"] - sales_rec["discount"]
sales_rec["customer_type"] =sales_rec["quantity"].apply(lambda qty:"Bulk Buyer" if qty>=3 else "Regular Buyer")
# Out:
#     order_id customer_name     category       city  quantity  unit_price  \
# 0     1001.0         Aarav  Electronics  Kathmandu       2.0     85000.0
# 4     1005.0         Bibek  Electronics    Pokhara       1.0     55000.0
# 6     1007.0         Nabin    Furniture   Lalitpur       2.0     25000.0
# 11    1013.0        Roshan  Electronics   Lalitpur       2.0     28000.0
# 15    1017.0         Manoj    Furniture  Kathmandu       1.0     22000.0
#
#    order_date     status     sales   profit  discount
# 0    1/5/2026  Completed  170000.0  34000.0   17000.0
# 4   1/20/2026  Cancelled   55000.0  11000.0    5500.0
# 6   1/25/2026  Completed   50000.0  10000.0    5000.0
# 11  2/18/2026  Completed   56000.0  11200.0    5600.0
# 15   3/5/2026  Completed   22000.0   4400.0    1100.0
#    customer_name     category     status
# 0          Aarav  Electronics  Completed
# 1           Sita    Furniture  Completed
# 6          Nabin    Furniture  Completed
# 11        Roshan  Electronics  Completed
# 15         Manoj    Furniture  Completed
# 17          Rita  Electronics  Completed
# 18        Bikash    Furniture  Completed

# %% [markdown]
# 10.Final Clean Dataset

# %%
print("Before:", original_shape, "After:", sales_rec.shape)
print(sales_rec.head(10))
# Out:
# Before: (27, 12) After: (20, 13)
#    order_id customer_name     category       city  quantity  unit_price  \
# 0    1001.0         Aarav  Electronics  Kathmandu       2.0     85000.0
# 1    1002.0          Sita    Furniture   Lalitpur       1.0     18000.0
# 2    1003.0         Rohan  Electronics  Bhaktapur       3.0      4500.0
# 3    1004.0        Anisha     Clothing  Kathmandu       2.0      6500.0
# 4    1005.0         Bibek  Electronics    Pokhara       1.0     55000.0
# 5    1006.0        Pragya        Books        NaN       4.0      2200.0
# 6    1007.0         Nabin    Furniture   Lalitpur       2.0     25000.0
# 7    1008.0         Samir     Clothing    Pokhara       3.0      7500.0
# 8    1010.0         Kiran        Books  Bhaktapur       2.0      3500.0
# 9    1011.0          Mina     Clothing  Kathmandu       5.0      1800.0
#
#   order_date     status     sales   profit  discount  total_amount  \
# 0   1/5/2026  Completed  170000.0  34000.0   17000.0      153000.0
# 1   1/8/2026  Completed   18000.0   3600.0     900.0       17100.0
# 2  1/12/2026    Pending   13500.0   2700.0     675.0       12825.0
# 3  1/15/2026  Completed   13000.0   2600.0     650.0       12350.0
# 4  1/20/2026  Cancelled   55000.0  11000.0    5500.0       49500.0
# 5  1/22/2026  Completed    8800.0   1760.0     440.0        8360.0
# 6  1/25/2026  Completed   50000.0  10000.0    5000.0       45000.0
# 7   2/2/2026    Pending   22500.0   4500.0    1125.0       21375.0
# 8   2/9/2026  Completed    7000.0   1400.0     350.0        6650.0
# 9  2/12/2026  Completed    9000.0   1800.0     450.0        8550.0
#
#    customer_type
# 0  Regular Buyer
# 1  Regular Buyer
# 2     Bulk Buyer
# 3  Regular Buyer
# 4  Regular Buyer
# 5     Bulk Buyer
# 6  Regular Buyer
# 7     Bulk Buyer
# 8  Regular Buyer
# 9     Bulk Buyer
